# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
from sonoscope import Sonoscope

# %%
Sonoscope.from_file(path="data/XC495704 - Eurasian Wren - Troglodytes troglodytes troglodytes.mp3", cmap="gray")

# %%
Sonoscope.from_url("https://xeno-canto.org/691131/download")
