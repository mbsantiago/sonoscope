# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: ANYWIDGET_HMR=1

# %%
from sonoscope import Sonoscope, Spectrogram

# %%
url = "https://upload.wikimedia.org/wikipedia/commons/9/9a/Dawn_Chorus_2020-05-06_0500.mp3?utm_source=commons.wikimedia.org&utm_campaign=index&utm_content=original"

# %%
Spectrogram(url=url, width=900, height=400, cmap="gray", frequency_scale="mel")
